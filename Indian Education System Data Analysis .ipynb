# %% [markdown]
# # Indian School Education Statistics
#
# Link:-https://www.kaggle.com/datasets/vidyapb/indian-school-education-statistics

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/indian education EDA/dropout-ratio-2012-2015.csv")

# %%
df.head()
# Out:
#          State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0   A & N Islands  2012-13         0.83          0.51          0.68
# 1   A & N Islands  2013-14         1.35          1.06          1.21
# 2   A & N Islands  2014-15         0.47          0.55          0.51
# 3  Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4  Andhra Pradesh  2013-14         4.31          4.39          4.35
#
#   Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys  \
# 0     Uppe_r_Primary                1.09                1.23            5.57
# 1                 NR                1.54                0.51            8.36
# 2               1.44                1.95                1.69           11.47
# 3               3.21                3.51                3.36           12.21
# 4               3.46                4.12                3.78           11.95
#
#   Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls  \
# ...

# %% [markdown]
# # Check Columns

# %%
df.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total'],
#       dtype='object')

# %% [markdown]
# # Check null values

# %%
df.isna()
# Out:
#      State_UT   year  Primary_Boys  Primary_Girls  Primary_Total  \
# 0       False  False         False          False          False
# 1       False  False         False          False          False
# 2       False  False         False          False          False
# 3       False  False         False          False          False
# 4       False  False         False          False          False
# ..        ...    ...           ...            ...            ...
# 105     False  False         False          False          False
# 106     False  False         False          False          False
# 107     False  False         False          False          False
# 108     False  False         False          False          False
# 109     False  False         False          False          False
#
#      Upper Primary_Boys  Upper Primary_Girls  Upper Primary_Total  \
# 0                 False                False                False
# ...

# %% [markdown]
# # Check the missing values in dataset

# %%
df.isna().any()
# Out:
# State_UT               False
# year                   False
# Primary_Boys           False
# Primary_Girls          False
# Primary_Total          False
# Upper Primary_Boys     False
# Upper Primary_Girls    False
# Upper Primary_Total    False
# Secondary _Boys        False
# Secondary _Girls       False
# Secondary _Total       False
# HrSecondary_Boys       False
# HrSecondary_Girls      False
# HrSecondary_Total      False
# dtype: bool

# %% [markdown]
# # Find the specifical data

# %%
data_wb=df[df['State_UT']=='West Bengal']
print (data_wb.head())
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# ...

# %%
data_wb
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# ...

# %%
data_wb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 104 to 106
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             3 non-null      object
#  1   year                 3 non-null      object
#  2   Primary_Boys         3 non-null      object
#  3   Primary_Girls        3 non-null      object
#  4   Primary_Total        3 non-null      object
#  5   Upper Primary_Boys   3 non-null      object
#  6   Upper Primary_Girls  3 non-null      object
#  7   Upper Primary_Total  3 non-null      object
#  8   Secondary _Boys      3 non-null      object
#  9   Secondary _Girls     3 non-null      object
#  10  Secondary _Total     3 non-null      object
#  11  HrSecondary_Boys     3 non-null      object
#  12  HrSecondary_Girls    3 non-null      object
#  13  HrSecondary_Total    3 non-null      object
# dtypes: object(14)
# memory usage: 360.0+ bytes

# %%
df['Primary_Boys'].values
# Out:
# array(['0.83', '1.35', '0.47', '3.3', '4.31', '6.57', '11.54', '15.84',
#        '11.51', '7.02', '8.19', '16.07', 'NR', '2.38', '0.35', 'NR', 'NR',
#        'NR', '4.24', '1.45', '3.08', 'NR', '1.05', '1.6', 'NR', '1.06',
#        '1.8', 'NR', 'NR', 'NR', 'NR', '0.08', '0.63', '0.21', '0.5',
#        '0.82', '1.48', '0.22', '5.54', '0.51', '0.57', '0.46', '6.8',
#        '5.53', '6.98', '7.36', '6.89', '5.91', '3.4', '2.42', '2.03',
#        'NR', 'NR', 'NR', '2.3', '0', 'NR', '5.75', '9.91', '6.48', '0.88',
#        '0.51', '1.26', '10.24', '17.27', '9.5', '11.32', '11.3', '10.35',
#        '24.27', '12.57', '10.17', '7.11', '19.09', '6.18', '3.63', '2.83',
#        '2.91', '0.25', '0.76', '0.36', '1.99', '1.35', '2.89', '7.2',
#        '7.76', '5.02', '4.78', '5.55', '3.75', '4.02', '0.53', 'NR',
#        '6.04', '2.21', '2.31', '3.63', '1.37', '10.53', '7.91', '9.08',
#        '1.14', '3.28', '4.37', '6.88', '3.44', '2.13', '4.68', '4.53',
#        '4.36'], dtype=object)

# %% [markdown]
# # Replace NR with 0

# %%
df=df.replace('NR',0)
df
# Out:
#            State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0     A & N Islands  2012-13         0.83          0.51          0.68
# 1     A & N Islands  2013-14         1.35          1.06          1.21
# 2     A & N Islands  2014-15         0.47          0.55          0.51
# 3    Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4    Andhra Pradesh  2013-14         4.31          4.39          4.35
# ..              ...      ...          ...           ...           ...
# 105     West Bengal  2013-14         3.44          2.37          2.91
# 106     West Bengal  2014-15         2.13          0.79          1.47
# 107       All India  2012-13         4.68          4.66          4.67
# 108       All India  2013-14         4.53          4.14          4.34
# 109       All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# ...

# %% [markdown]
# # Changing the datatype object to float

# %%
df['Primary_Boys'].values.astype(np.float32)
# Out:
# array([ 0.83,  1.35,  0.47,  3.3 ,  4.31,  6.57, 11.54, 15.84, 11.51,
#         7.02,  8.19, 16.07,  0.  ,  2.38,  0.35,  0.  ,  0.  ,  0.  ,
#         4.24,  1.45,  3.08,  0.  ,  1.05,  1.6 ,  0.  ,  1.06,  1.8 ,
#         0.  ,  0.  ,  0.  ,  0.  ,  0.08,  0.63,  0.21,  0.5 ,  0.82,
#         1.48,  0.22,  5.54,  0.51,  0.57,  0.46,  6.8 ,  5.53,  6.98,
#         7.36,  6.89,  5.91,  3.4 ,  2.42,  2.03,  0.  ,  0.  ,  0.  ,
#         2.3 ,  0.  ,  0.  ,  5.75,  9.91,  6.48,  0.88,  0.51,  1.26,
#        10.24, 17.27,  9.5 , 11.32, 11.3 , 10.35, 24.27, 12.57, 10.17,
#         7.11, 19.09,  6.18,  3.63,  2.83,  2.91,  0.25,  0.76,  0.36,
#         1.99,  1.35,  2.89,  7.2 ,  7.76,  5.02,  4.78,  5.55,  3.75,
#         4.02,  0.53,  0.  ,  6.04,  2.21,  2.31,  3.63,  1.37, 10.53,
#         7.91,  9.08,  1.14,  3.28,  4.37,  6.88,  3.44,  2.13,  4.68,
#         4.53,  4.36], dtype=float32)

# %%
#primary_boys=df['Primary_Boys'].values.astype(np.float)
df['Primary_Girls']=df['Primary_Girls'].values.astype(np.float32)

# %%
df['Upper Primary_Boys'].values
# Out:
# array(['Uppe_r_Primary', 0, '1.44', '3.21', '3.46', '5.09', '4.44',
#        '5.86', '5.31', '7.89', '7.6', '10.45', 0, '2.77', '4.14', 0,
#        '0.72', '0.01', '6.09', '4.09', '6.47', '2.59', '3.31', '3.7', 0,
#        '3.42', '3.14', 0, '3.13', '0.95', 0, 0, 0, '2.75', '3.52', '4.65',
#        '0.18', '1.97', '5.5', '0.52', '0.6', '0.5', '5.51', '3.86',
#        '4.98', '4.99', '7.19', '9.01', '4.96', '2.31', '3.46', 0, 0, 0,
#        '0.97', '1.16', '2.37', '6.79', '9.88', '7.78', '0.89', 0, '0.89',
#        '5.48', '7.48', '3.61', '8.43', '6.34', '6.77', '19.35', '6.61',
#        '5.46', '10.15', '18.08', '7.87', '4.1', '3.11', '4.11', '0.33',
#        '0.37', '0.44', '2.58', '2.52', '2.95', '2.86', '4.49', '2.54',
#        '2.6', '6.35', '2.07', '0.38', '4.38', 0, '4.63', '2.43', '3.1',
#        '3.21', '2.37', 0, 0, '0.78', 0, '1.78', '0.79', '6.29', '5.63',
#        '5.84', '2.3', '3.09', '3.49'], dtype=object)

# %%
df=df.replace('Uppe_r_Primary',0)

# %%
df['Upper Primary_Boys']=df['Upper Primary_Boys'].values.astype(np.float32)
df['Upper Primary_Girls']=df['Upper Primary_Girls'].values.astype(np.float32)

# %%
df['Secondary _Boys']=df['Secondary _Boys'].values.astype(np.float32)
df['Secondary _Girls']=df['Secondary _Girls'].values.astype(np.float32)

df['HrSecondary_Boys']=df['HrSecondary_Boys'].values.astype(np.float32)
df['HrSecondary_Girls']=df['HrSecondary_Girls'].values.astype(np.float32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    float32
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    float32
#  6   Upper Primary_Girls  110 non-null    float32
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    float32
#  9   Secondary _Girls     110 non-null    float32
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    float32
#  12  HrSecondary_Girls    110 non-null    float32
#  13  HrSecondary_Total    110 non-null    object
# dtypes: float32(7), object(7)
# memory usage: 9.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#        Primary_Girls  Upper Primary_Boys  Upper Primary_Girls  \
# count     110.000000          110.000000           110.000000
# mean        4.010818            3.581909             4.169455
# std         4.553512            3.388699             3.444964
# min         0.000000            0.000000             0.000000
# 25%         0.590000            0.782500             1.580000
# 50%         2.440000            3.120000             3.535000
# 75%         5.870000            5.422500             5.835000
# max        23.930000           19.350000            19.209999
#
#        Secondary _Boys  Secondary _Girls  HrSecondary_Boys  HrSecondary_Girls
# count       110.000000        110.000000        110.000000         110.000000
# mean         17.162273         16.311457          6.968000           4.979363
# std           8.931008          9.403942          7.404572           5.468029
# min           0.000000          0.000000          0.000000           0.000000
# ...

# %%
plt.figure(figsize= (35,15))

sns.countplot(x='State_UT',data=df)
# Out:
# <Axes: xlabel='State_UT', ylabel='count'>

# %%
data_wb.head()
# Out:
#         State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 104  West Bengal  2012-13         6.88          5.71           6.3
# 105  West Bengal  2013-14         3.44          2.37          2.91
# 106  West Bengal  2014-15         2.13          0.79          1.47
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# 104               6.29                4.16                5.18
# 105               5.63                 3.1                4.31
# 106               5.84                2.88                 4.3
#
#     Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys  \
# 104           14.95            19.41             17.3             7.81
# 105           16.73            19.77            18.34             8.03
# 106           16.33            19.06             17.8             8.18
#
#     HrSecondary_Girls HrSecondary_Total
# 104              8.49              8.13
# 105              7.76               7.9
# ...

# %% [markdown]
# #Q.1 What is the ratio of primary girls in west bengal by year basis

# %%
plt.bar(data_wb['Primary_Girls'],data_wb['year'])
plt.xlabel('Primary_Girls')
plt.ylabel('year')
plt.title("Year basis Primary_Girls ratio in west bengal")
plt.show()

# %% [markdown]
# #Q.2 What is the ratio of secondary girls in west bengal by year basis

# %%
plt.bar(data_wb['Secondary _Girls'],data_wb['year'])
plt.xlabel('Secondary_Girls')
plt.ylabel('year')
plt.title("Year basis Secondary_Girls ratio in west bengal")
plt.show()

# %% [markdown]
# #Q.3 What is the ratio of primary boys in west bengal by year basis

# %%
plt.bar(data_wb['Primary_Boys'],data_wb['year'])
plt.xlabel('Primary_Boys')
plt.ylabel('year')
plt.title("Year basis Primary_Boys ratio in west bengal")
plt.show()

# %% [markdown]
# #Q.4 What is the ratio of secondary boys in west bengal by year basis

# %%
plt.bar(data_wb['Secondary _Boys'],data_wb['year'])
plt.xlabel('Secondary_Boys')
plt.ylabel('year')
plt.title("Year basis Secondary_Boys ratio in west bengal")
plt.show()

# %% [markdown]
# #Q.5 What is the ratio of upper primary boys in west bengal by year basis

# %%
plt.bar(data_wb['Upper Primary_Boys'],data_wb['year'])
plt.xlabel('Upper Primary_Boys')
plt.ylabel('year')
plt.title("Year basis Upper Primary_Boys ratio in west bengal")
plt.show()

# %% [markdown]
# #Q.6 What is the ratio of upper primary girls in west bengal by year basis

# %%
plt.bar(data_wb['Upper Primary_Girls'],data_wb['year'])
plt.xlabel('Upper Primary_Girls')
plt.ylabel('year')
plt.title("Year basis Upper Primary_Girls ratio in west bengal")
plt.show()

# %%
plt.hist(df['HrSecondary_Girls'])
# Out:
# (array([52., 25., 18., 11.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.        ,  3.60500002,  7.21000004, 10.81499958, 14.42000008,
#         18.02499962, 21.62999916, 25.2349987 , 28.84000015, 32.44499969,
#         36.04999924]),
#  <BarContainer object of 10 artists>)

# %%
df.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Boys', 'Primary_Girls', 'Primary_Total',
#        'Upper Primary_Boys', 'Upper Primary_Girls', 'Upper Primary_Total',
#        'Secondary _Boys', 'Secondary _Girls', 'Secondary _Total',
#        'HrSecondary_Boys', 'HrSecondary_Girls', 'HrSecondary_Total'],
#       dtype='object')

# %%
#Outlier detection using boxplots
plt.figure(figsize=(20,15))
plt.subplot(4,4,1)
sns.boxplot(df['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(df['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(df['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(df['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(df['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(df['Secondary _Boys'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
df['HrSecondary_Girls']=df['HrSecondary_Girls'].clip(lower=df['HrSecondary_Girls'].quantile(0.05),upper=df['HrSecondary_Girls'].quantile(0.95))

# %%
df['HrSecondary_Boys']=df['HrSecondary_Boys'].clip(lower=df['HrSecondary_Boys'].quantile(0.05),upper=df['HrSecondary_Boys'].quantile(0.95))

# %%
df['HrSecondary_Boys']=df['Upper Primary_Boys'].clip(lower=df['Upper Primary_Boys'].quantile(0.05),upper=df['Upper Primary_Boys'].quantile(0.95))

# %%
df['HrSecondary_Boys']=df['Upper Primary_Girls'].clip(lower=df['Upper Primary_Girls'].quantile(0.05),upper=df['Upper Primary_Girls'].quantile(0.95))

# %%
df['Secondary _Girls']=df['Secondary _Girls'].clip(lower=df['Secondary _Girls'].quantile(0.05),upper=df['Secondary _Girls'].quantile(0.95))

# %%
df['Secondary _Boys']=df['Secondary _Boys'].clip(lower=df['Secondary _Boys'].quantile(0.05),upper=df['Secondary _Boys'].quantile(0.95))

# %%
#Outlier detection using boxplots
plt.figure(figsize=(20,15))
plt.subplot(4,4,1)
sns.boxplot(df['HrSecondary_Girls'])

plt.subplot(4,4,2)
sns.boxplot(df['HrSecondary_Boys'])

plt.subplot(4,4,3)
sns.boxplot(df['Upper Primary_Boys'])

plt.subplot(4,4,4)
sns.boxplot(df['Upper Primary_Girls'])

plt.subplot(4,4,5)
sns.boxplot(df['Secondary _Girls'])

plt.subplot(4,4,6)
sns.boxplot(df['Secondary _Boys'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...
